# %% [markdown]
# # Grad-CAM Interpretability Analysis
#
# This notebook loads the trained VGG-16 model and generates Grad-CAM visualizations to analyze the model's decision-making process.

# %%
import sys
sys.path.append('../src')

import torch
from analyze import load_model, run_analysis
from dataset import get_dataloaders

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# %%
# Load data
_, test_loader, classes = get_dataloaders(batch_size=32, data_dir='../data')

# Load model
model_path = "../outputs/models/vgg16_best.pth"
model = load_model(model_path, device)

# Run Grad-CAM Analysis
run_analysis(model, test_loader, classes, device, num_samples=5)
